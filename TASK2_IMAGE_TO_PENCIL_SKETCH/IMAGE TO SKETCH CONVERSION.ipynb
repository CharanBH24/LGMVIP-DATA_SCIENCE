# %% [markdown]
# ### LET'S GROW MORE INTERNSHIP

# %% [markdown]
# ### NAME :CHARAN SRIDHAR BHOGARAJU

# %% [markdown]
# ### TASK-2: IMAGE TO SKETCH CONVERSION

# %% [markdown]
# #### Description of Task:
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# ### IMPORT MODULES

# %%
import cv2

# %% [markdown]
# ### READING THE IMAGE

# %%
# image of the flower
img=cv2.imread("flower1.jpeg")

# %% [markdown]
# ### SHOWING OR DISPLAYING THE IMAGE

# %%
cv2.imshow("Flower picture",img)
cv2.waitKey(0)
# Out:
# 3

# %% [markdown]
# ### READING THE IMAGE IN RGB FORMAT

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ### CONVERTING ORIGINAL TO GREY SCALE IMAGE

# %%
g_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
g_img
# Out:
# array([[12, 12, 11, ...,  9, 11, 13],
#        [13, 12, 12, ..., 12, 12, 12],
#        [13, 13, 12, ..., 15, 14, 11],
#        ...,
#        [12, 12, 12, ..., 12, 11, 14],
#        [12, 12, 12, ..., 13, 11, 14],
#        [12, 12, 12, ..., 13, 12, 14]], dtype=uint8)

# %%
plt.imshow(g_img)

# %% [markdown]
# ### INVERTING THE GRAY SCALE IMAGE

# %%
inv_img=255-g_img
plt.imshow(inv_img)

# %% [markdown]
# ### BLUR THE IMAGE BY GAUSSIAN FUNCTION

# %%
blurr=cv2.GaussianBlur(inv_img,(15,15),0)
plt.imshow(blurr)

# %% [markdown]
# ### INVERTING THE BLURRED IMAGE TO PENCIL SKETCH

# %%
inv_blur=255-blurr
pencil_sketch=cv2.divide(g_img,inv_blur,scale=256.0)
plt.imshow(pencil_sketch)

# %% [markdown]
# ### ORIGINAL IMAGE AND PENCIL SKETCH

# %%
cv2.imshow("original",img)
cv2.imshow("pencil_sketch",pencil_sketch)
cv2.waitKey(0)
# Out:
# 3
